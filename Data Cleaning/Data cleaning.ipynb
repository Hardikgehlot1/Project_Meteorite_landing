# %%
import pandas as pd
import numpy as np

# %%
Data_df=pd.read_csv('../Resources/Meteorite_Landings.csv')
Data_df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall    year  \
# 0               Aachen    1    Valid           L5      21.0  Fell  1880.0
# 1               Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 2                 Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 4              Achiras  370    Valid           L6     780.0  Fell  1902.0
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 7                 Agen  392    Valid           H5   30000.0  Fell  1814.0
# 8               Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.index +=1

# %%
Data_df.head(10)
# Out:
#                    name   id nametype     recclass  mass (g)  fall    year  \
# 1                Aachen    1    Valid           L5      21.0  Fell  1880.0
# 2                Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 3                  Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 4              Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 5               Achiras  370    Valid           L6     780.0  Fell  1902.0
# 6              Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 7   Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 8                  Agen  392    Valid           H5   30000.0  Fell  1814.0
# 9                Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 10        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#       reclat    reclong           GeoLocation
# 1   50.77500    6.08333     (50.775, 6.08333)
# 2   56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 1 to 45716
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
Data_df.rename(columns={'name':'city_name','nametype':'type','recclass':'class'},inplace=True)

# %%
Data_df.head(10)
# Out:
#               city_name   id   type        class  mass (g)  fall    year  \
# 1                Aachen    1  Valid           L5      21.0  Fell  1880.0
# 2                Aarhus    2  Valid           H6     720.0  Fell  1951.0
# 3                  Abee    6  Valid          EH4  107000.0  Fell  1952.0
# 4              Acapulco   10  Valid  Acapulcoite    1914.0  Fell  1976.0
# 5               Achiras  370  Valid           L6     780.0  Fell  1902.0
# 6              Adhi Kot  379  Valid          EH4    4239.0  Fell  1919.0
# 7   Adzhi-Bogdo (stone)  390  Valid        LL3-6     910.0  Fell  1949.0
# 8                  Agen  392  Valid           H5   30000.0  Fell  1814.0
# 9                Aguada  398  Valid           L6    1620.0  Fell  1930.0
# 10        Aguila Blanca  417  Valid            L    1440.0  Fell  1920.0
#
#       reclat    reclong           GeoLocation
# 1   50.77500    6.08333     (50.775, 6.08333)
# 2   56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.count()
# Out:
# city_name      45716
# id             45716
# type           45716
# class          45716
# mass (g)       45585
# fall           45716
# year           45425
# reclat         38401
# reclong        38401
# GeoLocation    38401
# dtype: int64

# %%
Data_df = Data_df.dropna(how='any')

# %%
Data_df.count()
# Out:
# city_name      38115
# id             38115
# type           38115
# class          38115
# mass (g)       38115
# fall           38115
# year           38115
# reclat         38115
# reclong        38115
# GeoLocation    38115
# dtype: int64

# %%
Data_df['year']=Data_df['year'].astype(int)

# %%
Data_df['year'].unique()
# Out:
# array([1880, 1951, 1952, 1976, 1902, 1919, 1949, 1814, 1930, 1920, 1974,
#        1925, 1838, 1959, 1981, 1957, 2001, 1806, 1766, 2002, 1835, 1873,
#        1860, 1900, 1883, 1899, 1969, 2008, 1977, 1895, 1898, 1939, 1869,
#        1942, 1971, 1984, 1914, 1803, 1954, 1932, 1950, 1805, 2009, 1923,
#        1886, 1896, 1933, 1945, 1836, 1865, 1842, 1858, 1908, 1855, 1968,
#        1938, 1934, 1929, 1922, 1907, 1993, 1871, 1892, 1913, 1790, 1904,
#        1910, 1965, 2006, 1994, 2012, 1989, 1916, 1893, 1961, 1798, 2004,
#        1943, 1924, 1811, 1859, 1921, 1877, 1940, 1905, 1827, 1887, 1999,
#        1843, 1796, 1941, 1906, 1909, 1833, 1804, 1962, 1808, 1894, 1852,
#        1812, 1823, 2003, 2011, 1847, 1956, 1960, 2007, 1990, 1946, 1863,
#        1861, 1870, 1991, 1964, 1866, 1973, 1846, 1874, 1848, 1583, 1810,
#        1988, 1840, 1998, 1885, 1834, 1815, 1841, 2013, 1901, 1978, 1979,
#        1917, 1890, 1844, 1936, 1878, 1868, 1829, 1897, 1911, 1967, 1884,
# ...

# %%
from datetime import datetime as dt

# %%
#Data_df['year'] = pd.to_datetime(Data_df['year'],unit='s').dt.strftime('%Y-%m-%d')
Data_df['year'] = pd.to_datetime(Data_df['year'], format='%Y', errors='coerce')

# %%
Data_df.head()
# Out:
#   city_name   id   type        class  mass (g)  fall       year    reclat  \
# 1    Aachen    1  Valid           L5      21.0  Fell 1880-01-01  50.77500
# 2    Aarhus    2  Valid           H6     720.0  Fell 1951-01-01  56.18333
# 3      Abee    6  Valid          EH4  107000.0  Fell 1952-01-01  54.21667
# 4  Acapulco   10  Valid  Acapulcoite    1914.0  Fell 1976-01-01  16.88333
# 5   Achiras  370  Valid           L6     780.0  Fell 1902-01-01 -33.16667
#
#      reclong           GeoLocation
# 1    6.08333     (50.775, 6.08333)
# 2   10.23333  (56.18333, 10.23333)
# 3 -113.00000    (54.21667, -113.0)
# 4  -99.90000     (16.88333, -99.9)
# 5  -64.95000   (-33.16667, -64.95)

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38115 entries, 1 to 45716
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city_name    38115 non-null  object
#  1   id           38115 non-null  int64
#  2   type         38115 non-null  object
#  3   class        38115 non-null  object
#  4   mass (g)     38115 non-null  float64
#  5   fall         38115 non-null  object
#  6   year         38101 non-null  datetime64[ns]
#  7   reclat       38115 non-null  float64
#  8   reclong      38115 non-null  float64
#  9   GeoLocation  38115 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 3.2+ MB

# %%
split_data=Data_df['GeoLocation'].str.split(',',n=1,expand=True)

# %%
Data_df["latitude"] = split_data[0].str.strip("()")

# %%
Data_df["longitude"] = split_data[1].str.strip("()")

# %%
Data_df_cleaned=Data_df.drop(['GeoLocation'], axis=1)
# Out:
#         city_name     id   type                 class  mass (g)   fall  \
# 1          Aachen      1  Valid                    L5      21.0   Fell
# 2          Aarhus      2  Valid                    H6     720.0   Fell
# 3            Abee      6  Valid                   EH4  107000.0   Fell
# 4        Acapulco     10  Valid           Acapulcoite    1914.0   Fell
# 5         Achiras    370  Valid                    L6     780.0   Fell
# ...           ...    ...    ...                   ...       ...    ...
# 45712  Zillah 002  31356  Valid               Eucrite     172.0  Found
# 45713      Zinder  30409  Valid  Pallasite, ungrouped      46.0  Found
# 45714        Zlin  30410  Valid                    H4       3.3  Found
# 45715   Zubkovsky  31357  Valid                    L6    2167.0  Found
# 45716  Zulu Queen  30414  Valid                  L3.7     200.0  Found
#
#             year    reclat    reclong   latitude    longitude
# ...

# %%
Data_cleaned_df=Data_df_cleaned.drop(['reclat','reclong'], axis=1)

# %%
Data_cleaned_df.head()
# Out:
#   city_name   id   type        class  mass (g)  fall       year   latitude  \
# 1    Aachen    1  Valid           L5      21.0  Fell 1880-01-01     50.775
# 2    Aarhus    2  Valid           H6     720.0  Fell 1951-01-01   56.18333
# 3      Abee    6  Valid          EH4  107000.0  Fell 1952-01-01   54.21667
# 4  Acapulco   10  Valid  Acapulcoite    1914.0  Fell 1976-01-01   16.88333
# 5   Achiras  370  Valid           L6     780.0  Fell 1902-01-01  -33.16667
#
#    longitude
# 1    6.08333
# 2   10.23333
# 3     -113.0
# 4      -99.9
# 5     -64.95

# %%
Data_cleaned_df.to_csv('../Resources/Meteorite_Landings_cleaned.csv',index=False)
