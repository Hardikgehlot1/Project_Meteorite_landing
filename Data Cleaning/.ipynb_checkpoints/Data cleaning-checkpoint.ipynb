# %%
import pandas as pd
import numpy as np

# %%
Data_df=pd.read_csv('../Resources/Meteorite_Landings.csv')
Data_df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall    year  \
# 0               Aachen    1    Valid           L5      21.0  Fell  1880.0
# 1               Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 2                 Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 4              Achiras  370    Valid           L6     780.0  Fell  1902.0
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 7                 Agen  392    Valid           H5   30000.0  Fell  1814.0
# 8               Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.index +=1

# %%
Data_df.head(10)
# Out:
#                    name   id nametype     recclass  mass (g)  fall    year  \
# 1                Aachen    1    Valid           L5      21.0  Fell  1880.0
# 2                Aarhus    2    Valid           H6     720.0  Fell  1951.0
# 3                  Abee    6    Valid          EH4  107000.0  Fell  1952.0
# 4              Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0
# 5               Achiras  370    Valid           L6     780.0  Fell  1902.0
# 6              Adhi Kot  379    Valid          EH4    4239.0  Fell  1919.0
# 7   Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell  1949.0
# 8                  Agen  392    Valid           H5   30000.0  Fell  1814.0
# 9                Aguada  398    Valid           L6    1620.0  Fell  1930.0
# 10        Aguila Blanca  417    Valid            L    1440.0  Fell  1920.0
#
#       reclat    reclong           GeoLocation
# 1   50.77500    6.08333     (50.775, 6.08333)
# 2   56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 1 to 45716
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  float64
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
Data_df.rename(columns={'name':'City_Name','nametype':'Type'},inplace=True)

# %%
Data_df.head(10)
# Out:
#               City_Name   id   Type     recclass  mass (g)  fall    year  \
# 1                Aachen    1  Valid           L5      21.0  Fell  1880.0
# 2                Aarhus    2  Valid           H6     720.0  Fell  1951.0
# 3                  Abee    6  Valid          EH4  107000.0  Fell  1952.0
# 4              Acapulco   10  Valid  Acapulcoite    1914.0  Fell  1976.0
# 5               Achiras  370  Valid           L6     780.0  Fell  1902.0
# 6              Adhi Kot  379  Valid          EH4    4239.0  Fell  1919.0
# 7   Adzhi-Bogdo (stone)  390  Valid        LL3-6     910.0  Fell  1949.0
# 8                  Agen  392  Valid           H5   30000.0  Fell  1814.0
# 9                Aguada  398  Valid           L6    1620.0  Fell  1930.0
# 10        Aguila Blanca  417  Valid            L    1440.0  Fell  1920.0
#
#       reclat    reclong           GeoLocation
# 1   50.77500    6.08333     (50.775, 6.08333)
# 2   56.18333   10.23333  (56.18333, 10.23333)
# ...

# %%
Data_df.fillna(0,inplace=True)
#Data_df=Data_df['year'].replace('',0)

# %%
Data_df.head()
# Out:
#   City_Name   id   Type     recclass  mass (g)  fall    year    reclat  \
# 1    Aachen    1  Valid           L5      21.0  Fell  1880.0  50.77500
# 2    Aarhus    2  Valid           H6     720.0  Fell  1951.0  56.18333
# 3      Abee    6  Valid          EH4  107000.0  Fell  1952.0  54.21667
# 4  Acapulco   10  Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 5   Achiras  370  Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 1    6.08333     (50.775, 6.08333)
# 2   10.23333  (56.18333, 10.23333)
# 3 -113.00000    (54.21667, -113.0)
# 4  -99.90000     (16.88333, -99.9)
# 5  -64.95000   (-33.16667, -64.95)

# %%
Data_df['year'] = Data_df['year'].astype(int)

# %%
Data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 1 to 45716
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City_Name    45716 non-null  object
#  1   id           45716 non-null  int64
#  2   Type         45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45716 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45716 non-null  int32
#  7   reclat       45716 non-null  float64
#  8   reclong      45716 non-null  float64
#  9   GeoLocation  45716 non-null  object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 3.3+ MB

# %%
Data_df.head()
# Out:
#   City_Name   id   Type     recclass  mass (g)  fall  year    reclat  \
# 1    Aachen    1  Valid           L5      21.0  Fell  1880  50.77500
# 2    Aarhus    2  Valid           H6     720.0  Fell  1951  56.18333
# 3      Abee    6  Valid          EH4  107000.0  Fell  1952  54.21667
# 4  Acapulco   10  Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 5   Achiras  370  Valid           L6     780.0  Fell  1902 -33.16667
#
#      reclong           GeoLocation
# 1    6.08333     (50.775, 6.08333)
# 2   10.23333  (56.18333, 10.23333)
# 3 -113.00000    (54.21667, -113.0)
# 4  -99.90000     (16.88333, -99.9)
# 5  -64.95000   (-33.16667, -64.95)

# %%
from datetime import datetime as dt

# %%
Data_df['year'] = pd.to_datetime(Data_df['year'],format = '%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10308\3872130703.py in <module>
# ----> 1 Data_df['year'] = pd.to_datetime(Data_df['year'],format = '%Y')
#
# ...

# %%
Data_df.head(10)
# Out:
#               City_Name   id   Type     recclass  mass (g)  fall  year  \
# 1                Aachen    1  Valid           L5      21.0  Fell  1970
# 2                Aarhus    2  Valid           H6     720.0  Fell  1970
# 3                  Abee    6  Valid          EH4  107000.0  Fell  1970
# 4              Acapulco   10  Valid  Acapulcoite    1914.0  Fell  1970
# 5               Achiras  370  Valid           L6     780.0  Fell  1970
# 6              Adhi Kot  379  Valid          EH4    4239.0  Fell  1970
# 7   Adzhi-Bogdo (stone)  390  Valid        LL3-6     910.0  Fell  1970
# 8                  Agen  392  Valid           H5   30000.0  Fell  1970
# 9                Aguada  398  Valid           L6    1620.0  Fell  1970
# 10        Aguila Blanca  417  Valid            L    1440.0  Fell  1970
#
#       reclat    reclong           GeoLocation
# 1   50.77500    6.08333     (50.775, 6.08333)
# 2   56.18333   10.23333  (56.18333, 10.23333)
# 3   54.21667 -113.00000    (54.21667, -113.0)
# ...
